# %% [markdown]
# # FIDUCIA Fase 4 - Fraud Modeling
#
# Notebook reproducible de evidencia. La logica productiva vive en `ml/` y `scripts/`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from ml.evaluation.eda import run_eda
from ml.training.train import train_fraud_model

# %% [markdown]
# ## 1. Carga, validacion y EDA

# %%
eda = run_eda()
eda['target_distribution']

# %% [markdown]
# ## 2. Entrenamiento, evaluacion y seleccion

# %%
result = train_fraud_model(seed=42)
result['metadata']['selected_model'], result['metadata']['metrics']

# %% [markdown]
# ## 3. Conclusiones
#
# El modelo seleccionado funciona como senal experimental de apoyo al analisis. No confirma fraude real ni debe automatizar bloqueos.
